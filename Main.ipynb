# %% [markdown]
# # NETFLIX
# ---
# 0. NETFILX 소개
#     - ....
# 1. 데이터 수집
#     - Netflix_Data
#     - Netflix_Original Data
#     - Rating_Data
#     - Netflix_Data + Netflix_Original Data + Rating_Data
# 2. 데이터 전처리
#     - 결측치 수정 및 제거
#     - Feature engineering
# 3. 데이터 EDA
#     - Score, avg, total 먼저 비교 !!
#
# 4. 결론

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings 

plt.style.use('ggplot')
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 0. NETFILX 소개

# %% [markdown]
# ## 1. 데이터 수집
# ---

# %% [markdown]
# ### Netflix_Data
# </br>
#
# __✅COLUMNS__
# </br>
#
# | SHOW_ID | 영화나 티비쇼의 고유번호  |
# | --- | --- |
# | TYPE | 영화인지 티비쇼인지 구별 |
# | TITLE | 영화, 티비쇼의 제목 |
# | DIRECTOR | 영화감독 |
# | CAST | 영화, 쇼에 출연한 배우들 |
# | COUNTRY | 영화나 쇼가 제작된 나라 |
# | DATE_ADDED | 넷플릭스에 드라마나 영화가 방영된 날짜. 2008.01 ~ 2021.09.25 |
# | RELEASE_YEAR | 실제 드라마나 영화가 방영된 연도. 1925 ~ 2021 |
# | RATING | 영화/쇼의 시청 등급 |
# | DURATION | 방영기간 |
# | LISTED_IN | 장르 |
# | DESCRIPTION | 줄거리 |

# %%
path = './data'
Net_df = pd.read_csv(path+"/fixed_netflix_df.csv")
Net_df.head()
# Out:
#   show_id     type             director                  title  \
# 0      s1    Movie      Kirsten Johnson   Dick Johnson Is Dead
# 1      s2  TV Show       Nosipho Dumisa          Blood & Water
# 2      s3  TV Show      Julien Leclercq              Ganglands
# 3      s4  TV Show  Jacquelyn C. Migdal  Jailbirds New Orleans
# 4      s5  TV Show         Raghav Subbu           Kota Factory
#
#                                                 cast        country  \
# 0  Michael Hilow, Dick Johnson, Chad Knorr, Vasth...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         France
# 3                                               NONE  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added                                        description  \
# 0  September 25, 2021  As her father nears the end of his life, filmm...
# 1  September 24, 2021  After crossing paths at a party, a Cape Town t...
# 2  September 24, 2021  To protect his family from a powerful drug lor...
# 3  September 24, 2021  Feuds, flirtations and toilet talk go down amo...
# 4  September 24, 2021  In a city of coaching centers known to train I...
#
#     duration                                          listed_in rating  \
# 0     90 min                                      Documentaries  PG-13
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries  TV-MA
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...  TV-MA
# 3   1 Season                             Docuseries, Reality TV  TV-MA
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...  TV-MA
#
#    release_year
# 0          2020
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %% [markdown]
# ### Netflix_Original Data
# __✅ COLUMNS__

# %%
OG = pd.read_csv("./data/NetflixOriginals.csv", encoding="ISO-8859-1")
OG = OG["Title"].tolist()
OG[:10]
# Out:
# ['Enter the Anime',
#  'Dark Forces',
#  'The App',
#  'The Open House',
#  'Kaali Khuhi',
#  'Drive',
#  'Leyla Everlasting',
#  'The Last Days of American Crime',
#  'Paradox',
#  'Sardar Ka Grandson']

# %% [markdown]
# ### Rating_Data
# __✅ COLUMNS__

# %%
Rating_df = pd.read_csv("./data/Netflix_Rating.csv")
Rating_df.head()
# Out:
#                    Title  Avg    Total  Total_males  Total_Females  \
# 0   Dick Johnson Is Dead  7.4   6241.0       3780.0          592.0
# 1          Blood & Water  6.7   2952.0        603.0          867.0
# 2              Ganglands  7.0   2349.0       1297.0          117.0
# 3  Jailbirds New Orleans  6.7    194.0         57.0           60.0
# 4           Kota Factory  9.3  66527.0      19278.0          984.0
#
#    All_below_18  All_18_29  All_30_44  All_over_45  Males_below_18  ...  \
# 0          12.0     1050.0     2321.0        817.0            10.0  ...
# 1          10.0      416.0      644.0        281.0             4.0  ...
# 2           1.0       99.0      574.0        648.0             1.0  ...
# 3           0.0       19.0       63.0         30.0             0.0  ...
# 4         144.0    10004.0     5687.0        340.0           134.0  ...
#
#    Males_rank_below_18  Males_rank_18_29  Males_rank_30_44  \
# 0                  7.9               7.7               7.4
# 1                  5.5               6.6               5.9
# 2                  6.0               6.9               6.8
# 3                  0.0               6.4               6.3
# 4                  9.6               9.2               8.5
#
#    Males_rank_over_45  Females_rank_below_18  Females_rank_18_29  \
# 0                 7.1                    8.0                 7.8
# 1                 4.9                    5.0                 6.9
# 2                 7.0                    0.0                 5.8
# 3                 6.6                    0.0                 6.2
# 4                 6.4                    4.3                 9.2
#
#    Females_rank_30_44 Females_rank_over_45  Avg_rank_males  Avg_rank_Females
# 0                 7.4                  7.3             7.4               7.5
# 1                 7.0                  7.0             5.9               7.0
# 2                 6.9                  7.0             6.9               7.0
# 3                 6.9                  6.9             6.5               6.9
# 4                 7.5                  5.7             9.0               8.5
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Netflix_Data + Netflix_Original Data +  Rating_Data

# %%
# Netflix_Data + Netflix_Original Data 
og = []
for name in Net_df.title.values:
    if name in OG:
        og.append(1)
    else:
        og.append(0)

Net_df["Original"] = og
Net_df["Original"].value_counts()
# Out:
# 0    8301
# 1     506
# Name: Original, dtype: int64

# %%
df = pd.merge(Net_df, Rating_df, left_on= "title", right_on= "Title")
df.head()
# Out:
#   show_id     type             director                  title  \
# 0      s1    Movie      Kirsten Johnson   Dick Johnson Is Dead
# 1      s2  TV Show       Nosipho Dumisa          Blood & Water
# 2      s3  TV Show      Julien Leclercq              Ganglands
# 3      s4  TV Show  Jacquelyn C. Migdal  Jailbirds New Orleans
# 4      s5  TV Show         Raghav Subbu           Kota Factory
#
#                                                 cast        country  \
# 0  Michael Hilow, Dick Johnson, Chad Knorr, Vasth...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         France
# 3                                               NONE  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added                                        description  \
# 0  September 25, 2021  As her father nears the end of his life, filmm...
# 1  September 24, 2021  After crossing paths at a party, a Cape Town t...
# 2  September 24, 2021  To protect his family from a powerful drug lor...
# 3  September 24, 2021  Feuds, flirtations and toilet talk go down amo...
# 4  September 24, 2021  In a city of coaching centers known to train I...
#
#     duration                                          listed_in  ...  \
# 0     90 min                                      Documentaries  ...
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries  ...
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...  ...
# 3   1 Season                             Docuseries, Reality TV  ...
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...  ...
#
#   Males_rank_below_18  Males_rank_18_29  Males_rank_30_44 Males_rank_over_45  \
# 0                 7.9               7.7               7.4                7.1
# 1                 5.5               6.6               5.9                4.9
# 2                 6.0               6.9               6.8                7.0
# 3                 0.0               6.4               6.3                6.6
# 4                 9.6               9.2               8.5                6.4
#
#    Females_rank_below_18  Females_rank_18_29  Females_rank_30_44  \
# 0                    8.0                 7.8                 7.4
# 1                    5.0                 6.9                 7.0
# 2                    0.0                 5.8                 6.9
# 3                    0.0                 6.2                 6.9
# 4                    4.3                 9.2                 7.5
#
#    Females_rank_over_45  Avg_rank_males  Avg_rank_Females
# 0                   7.3             7.4               7.5
# 1                   7.0             5.9               7.0
# 2                   7.0             6.9               7.0
# 3                   6.9             6.5               6.9
# 4                   5.7             9.0               8.5
#
# [5 rows x 45 columns]

# %% [markdown]
# ## 2. 데이터 전처리
#
# - 결측치 수정 및 제거
#     - 결측치 확인 및 크롤링으로 추가
#     - 확인되지 않는 행 제거
#     - 사용하지 않는 컬럼 제거
# - Feature engineering
#     - 영화 관람 등급, 티비 관람 등급
#     - score(평점, 리뷰 수)...

# %% [markdown]
# ### 결측치 수정 및 제거

# %%
# 밀린 데이터 채우고, 없는 데이터 제거
df[df['rating'] == '74 min']

df[df['rating'] == '66 min']

df[df['rating'] == '84 min']

index = df[df['rating'] == '66 min'].index 
df.loc[index,'duration'] = df.loc[index,'rating']
df.loc[index,'rating'] = np.nan

index = df[df['rating'] == '74 min'].index
df.loc[index,'duration'] = df.loc[index,'rating']
df.loc[index,'rating'] = np.nan

index = df[df['rating'] == '84 min'].index
df.loc[index,'duration'] = df.loc[index,'rating']
df.loc[index,'rating'] = np.nan

df['rating'].unique()

df.isnull().sum()
# Out:
# show_id                   0
# type                      0
# director                  0
# title                     0
# cast                      0
# country                   0
# date_added               10
# description               0
# duration                  0
# listed_in                 0
# rating                    7
# release_year              0
# Original                  0
# Title                     0
# Avg                       0
# Total                     0
# Total_males               0
# Total_Females             0
# All_below_18              0
# All_18_29                 0
# All_30_44                 0
# All_over_45               0
# Males_below_18            0
# Males_18_29               0
# Males_30_44               0
# Males_over_45             0
# Females_below_18          0
# Females_18_29             0
# Females_30_44             0
# Females_over_45           0
# Title_ID                  0
# All_rank_below_18         0
# All_rank_18_29            0
# All_rank_30_44            0
# All_rank_over_45          0
# Males_rank_below_18       0
# Males_rank_18_29          0
# Males_rank_30_44          0
# Males_rank_over_45        0
# Females_rank_below_18     0
# Females_rank_18_29        0
# Females_rank_30_44        0
# Females_rank_over_45      0
# Avg_rank_males            0
# Avg_rank_Females          0
# dtype: int64

# %%
# NOT FOUND 제거
df.drop(df[df["Title_ID"] == "NOT FOUND"].index, inplace=True)
df = df.reset_index(drop=True)

# %%
#NO RATINGS
df.drop(df[df["Avg"] == 0].index, inplace=True)
df.reset_index(drop=True)
# Out:
#      show_id     type             director                  title  \
# 0         s1    Movie      Kirsten Johnson   Dick Johnson Is Dead
# 1         s2  TV Show       Nosipho Dumisa          Blood & Water
# 2         s3  TV Show      Julien Leclercq              Ganglands
# 3         s4  TV Show  Jacquelyn C. Migdal  Jailbirds New Orleans
# 4         s5  TV Show         Raghav Subbu           Kota Factory
# ...      ...      ...                  ...                    ...
# 8425   s8803    Movie        David Fincher                 Zodiac
# 8426   s8804  TV Show          Jiyeon Park            Zombie Dumb
# 8427   s8805    Movie      Ruben Fleischer             Zombieland
# 8428   s8806    Movie         Peter Hewitt                   Zoom
# 8429   s8807    Movie          Mozez Singh                 Zubaan
#
#                                                    cast  \
# 0     Michael Hilow, Dick Johnson, Chad Knorr, Vasth...
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                  NONE
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...                                                 ...
# 8425  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8426                                               NONE
# 8427  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8428  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8429  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                               country          date_added  \
# 0                       United States  September 25, 2021
# 1                        South Africa  September 24, 2021
# 2                              France  September 24, 2021
# 3                       United States  September 24, 2021
# 4                               India  September 24, 2021
# ...                               ...                 ...
# 8425                    United States   November 20, 2019
# 8426  Production Company Project Page        July 1, 2019
# 8427                    United States    November 1, 2019
# 8428                    United States    January 11, 2020
# 8429                            India       March 2, 2019
#
#                                             description   duration  \
# 0     As her father nears the end of his life, filmm...     90 min
# 1     After crossing paths at a party, a Cape Town t...  2 Seasons
# 2     To protect his family from a powerful drug lor...   1 Season
# 3     Feuds, flirtations and toilet talk go down amo...   1 Season
# 4     In a city of coaching centers known to train I...  2 Seasons
# ...                                                 ...        ...
# 8425  A political cartoonist, a crime reporter and a...    158 min
# 8426  While living alone in a spooky town, a young g...  2 Seasons
# 8427  Looking to survive in a world taken over by zo...     88 min
# 8428  Dragged from civilian life, a former superhero...     88 min
# 8429  A scrappy but poor boy worms his way into a ty...    111 min
#
#                                               listed_in  ...  \
# 0                                         Documentaries  ...
# 1       International TV Shows, TV Dramas, TV Mysteries  ...
# 2     Crime TV Shows, International TV Shows, TV Act...  ...
# 3                                Docuseries, Reality TV  ...
# 4     International TV Shows, Romantic TV Shows, TV ...  ...
# ...                                                 ...  ...
# 8425                     Cult Movies, Dramas, Thrillers  ...
# 8426             Kids' TV, Korean TV Shows, TV Comedies  ...
# 8427                            Comedies, Horror Movies  ...
# 8428                 Children & Family Movies, Comedies  ...
# 8429     Dramas, International Movies, Music & Musicals  ...
#
#      Males_rank_below_18  Males_rank_18_29  Males_rank_30_44  \
# 0                    7.9               7.7               7.4
# 1                    5.5               6.6               5.9
# 2                    6.0               6.9               6.8
# 3                    0.0               6.4               6.3
# 4                    9.6               9.2               8.5
# ...                  ...               ...               ...
# 8425                 8.2               7.9               7.7
# 8426                 0.0               3.5               8.0
# 8427                 7.7               7.7               7.6
# 8428                 3.1               4.0               3.9
# 8429                 0.0               6.5               5.7
#
#      Males_rank_over_45  Females_rank_below_18  Females_rank_18_29  \
# 0                   7.1                    8.0                 7.8
# 1                   4.9                    5.0                 6.9
# 2                   7.0                    0.0                 5.8
# 3                   6.6                    0.0                 6.2
# 4                   6.4                    4.3                 9.2
# ...                 ...                    ...                 ...
# 8425                7.5                    7.6                 7.7
# 8426                0.0                    0.0                 0.0
# 8427                7.4                    7.2                 7.6
# 8428                4.6                    0.0                 5.2
# 8429                6.1                    0.0                 4.9
#
#       Females_rank_30_44  Females_rank_over_45  Avg_rank_males  \
# 0                    7.4                   7.3             7.4
# 1                    7.0                   7.0             5.9
# 2                    6.9                   7.0             6.9
# 3                    6.9                   6.9             6.5
# 4                    7.5                   5.7             9.0
# ...                  ...                   ...             ...
# 8425                 7.4                   7.5             7.7
# 8426                 0.0                  10.0             5.0
# 8427                 7.6                   7.6             7.6
# 8428                 4.9                   5.5             4.2
# 8429                 5.8                   6.3             6.0
#
#       Avg_rank_Females
# 0                  7.5
# 1                  7.0
# 2                  7.0
# 3                  6.9
# 4                  8.5
# ...                ...
# 8425               7.5
# 8426              10.0
# 8427               7.6
# 8428               5.2
# 8429               5.9
#
# [8430 rows x 45 columns]

# %%
# 없는 rating data 제거 , 8807 - 202 - 10(중복있을듯 아마...) = 8598 
df.drop(df[df["rating"].isnull()].index, inplace=True)
df = df.reset_index(drop=True)

# %%
# 사용하지 않는 컬럼 제거
# date_added
# show_id
# desciption
# Title_ID

df.drop(["date_added", "show_id", "description", "Title_ID"], axis = 1, inplace=True)
df.head()
# Out:
#       type             director                  title  \
# 0    Movie      Kirsten Johnson   Dick Johnson Is Dead
# 1  TV Show       Nosipho Dumisa          Blood & Water
# 2  TV Show      Julien Leclercq              Ganglands
# 3  TV Show  Jacquelyn C. Migdal  Jailbirds New Orleans
# 4  TV Show         Raghav Subbu           Kota Factory
#
#                                                 cast        country  \
# 0  Michael Hilow, Dick Johnson, Chad Knorr, Vasth...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         France
# 3                                               NONE  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#     duration                                          listed_in rating  \
# 0     90 min                                      Documentaries  PG-13
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries  TV-MA
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...  TV-MA
# 3   1 Season                             Docuseries, Reality TV  TV-MA
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...  TV-MA
#
#    release_year  Original  ... Males_rank_below_18  Males_rank_18_29  \
# 0          2020         1  ...                 7.9               7.7
# 1          2021         0  ...                 5.5               6.6
# 2          2021         0  ...                 6.0               6.9
# 3          2021         0  ...                 0.0               6.4
# 4          2021         0  ...                 9.6               9.2
#
#    Males_rank_30_44  Males_rank_over_45  Females_rank_below_18  \
# 0               7.4                 7.1                    8.0
# 1               5.9                 4.9                    5.0
# 2               6.8                 7.0                    0.0
# 3               6.3                 6.6                    0.0
# 4               8.5                 6.4                    4.3
#
#    Females_rank_18_29  Females_rank_30_44  Females_rank_over_45  \
# 0                 7.8                 7.4                   7.3
# 1                 6.9                 7.0                   7.0
# 2                 5.8                 6.9                   7.0
# 3                 6.2                 6.9                   6.9
# 4                 9.2                 7.5                   5.7
#
#    Avg_rank_males  Avg_rank_Females
# 0             7.4               7.5
# 1             5.9               7.0
# 2             6.9               7.0
# 3             6.5               6.9
# 4             9.0               8.5
#
# [5 rows x 41 columns]

# %%
# 최종 데이터
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8423 entries, 0 to 8422
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   type                   8423 non-null   object
#  1   director               8423 non-null   object
#  2   title                  8423 non-null   object
#  3   cast                   8423 non-null   object
#  4   country                8423 non-null   object
#  5   duration               8423 non-null   object
#  6   listed_in              8423 non-null   object
#  7   rating                 8423 non-null   object
#  8   release_year           8423 non-null   int64
#  9   Original               8423 non-null   int64
#  10  Title                  8423 non-null   object
#  11  Avg                    8423 non-null   float64
#  12  Total                  8423 non-null   float64
#  13  Total_males            8423 non-null   float64
#  14  Total_Females          8423 non-null   float64
#  15  All_below_18           8423 non-null   float64
#  16  All_18_29              8423 non-null   float64
#  17  All_30_44              8423 non-null   float64
#  18  All_over_45            8423 non-null   float64
#  19  Males_below_18         8423 non-null   float64
#  20  Males_18_29            8423 non-null   float64
#  21  Males_30_44            8423 non-null   float64
#  22  Males_over_45          8423 non-null   float64
#  23  Females_below_18       8423 non-null   float64
#  24  Females_18_29          8423 non-null   float64
#  25  Females_30_44          8423 non-null   float64
#  26  Females_over_45        8423 non-null   float64
#  27  All_rank_below_18      8423 non-null   float64
#  28  All_rank_18_29         8423 non-null   float64
#  29  All_rank_30_44         8423 non-null   float64
#  30  All_rank_over_45       8423 non-null   float64
#  31  Males_rank_below_18    8423 non-null   float64
#  32  Males_rank_18_29       8423 non-null   float64
#  33  Males_rank_30_44       8423 non-null   float64
#  34  Males_rank_over_45     8423 non-null   float64
#  35  Females_rank_below_18  8423 non-null   float64
#  36  Females_rank_18_29     8423 non-null   float64
#  37  Females_rank_30_44     8423 non-null   float64
#  38  Females_rank_over_45   8423 non-null   float64
#  39  Avg_rank_males         8423 non-null   object
#  40  Avg_rank_Females       8423 non-null   object
# dtypes: float64(28), int64(2), object(11)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# type columns
# - 영화: 0
# - 티비쇼: 1

# %%
def type_col(col):
    if col == 'Movie':
        return 0
    else:
        return 1

# %%
df['type'] = df["type"].apply(type_col)
df.head()
# Out:
#    type             director                  title  \
# 0     0      Kirsten Johnson   Dick Johnson Is Dead
# 1     1       Nosipho Dumisa          Blood & Water
# 2     1      Julien Leclercq              Ganglands
# 3     1  Jacquelyn C. Migdal  Jailbirds New Orleans
# 4     1         Raghav Subbu           Kota Factory
#
#                                                 cast        country  \
# 0  Michael Hilow, Dick Johnson, Chad Knorr, Vasth...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...         France
# 3                                               NONE  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#     duration                                          listed_in rating  \
# 0     90 min                                      Documentaries  PG-13
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries  TV-MA
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...  TV-MA
# 3   1 Season                             Docuseries, Reality TV  TV-MA
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...  TV-MA
#
#    release_year  Original  ... Males_rank_below_18  Males_rank_18_29  \
# 0          2020         1  ...                 7.9               7.7
# 1          2021         0  ...                 5.5               6.6
# 2          2021         0  ...                 6.0               6.9
# 3          2021         0  ...                 0.0               6.4
# 4          2021         0  ...                 9.6               9.2
#
#    Males_rank_30_44  Males_rank_over_45  Females_rank_below_18  \
# 0               7.4                 7.1                    8.0
# 1               5.9                 4.9                    5.0
# 2               6.8                 7.0                    0.0
# 3               6.3                 6.6                    0.0
# 4               8.5                 6.4                    4.3
#
#    Females_rank_18_29  Females_rank_30_44  Females_rank_over_45  \
# 0                 7.8                 7.4                   7.3
# 1                 6.9                 7.0                   7.0
# 2                 5.8                 6.9                   7.0
# 3                 6.2                 6.9                   6.9
# 4                 9.2                 7.5                   5.7
#
#    Avg_rank_males  Avg_rank_Females
# 0             7.4               7.5
# 1             5.9               7.0
# 2             6.9               7.0
# 3             6.5               6.9
# 4             9.0               8.5
#
# [5 rows x 41 columns]

# %% [markdown]
# rating col
# - 전체관람가('G', 'PG', 'TV-Y', 'TV-7', 'TV-Y7-FV', 'TV-G'): 0
# - 12,15세 관람가('PG-13', 'TV-PG', 'TV-14'): 1
# - 15, 청불('R', 'NC-17', 'NR', 'UR', 'TV-MA'): 2

# %%
def rating_col(col):
    if col in ['G', 'PG', 'TV-Y','TV-Y7', 'TV-Y7-FV', 'TV-G']:
        return 0
    elif col in ['PG-13', 'TV-PG', 'TV-14']:
        return 1
    elif col in ['R', 'NC-17', 'NR', 'UR', 'TV-MA']:
        return 2
    else:
        return col

# %%
df['rating'] = df["rating"].apply(rating_col)
df['rating']
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 8418    2
# 8419    0
# 8420    2
# 8421    0
# 8422    1
# Name: rating, Length: 8423, dtype: int64

# %% [markdown]
# ### Score : 평점 * 리뷰 수

# %%
df["Score"] = df["Avg"] * df["Total"] 
df["Score_normal"] = (df["Score"] - df["Score"].mean())/df["Score"].std() + 1 #정규화

# %%
# min 열만 가져오기
duration_col = df['duration'].str.endswith('min')

# %%
mins_duration = df[duration_col]
mins_duration.head()
# Out:
#     type                       director                             title  \
# 0      0                Kirsten Johnson              Dick Johnson Is Dead
# 6      0  Robert Cullen, José Luis Ucha  My Little Pony: A New Generation
# 7      0                   Haile Gerima                           Sankofa
# 9      0                 Theodore Melfi                      The Starling
# 12     0            Christian Schwochow                      Je Suis Karl
#
#                                                  cast  \
# 0   Michael Hilow, Dick Johnson, Chad Knorr, Vasth...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country duration  \
# 0                                       United States   90 min
# 6                                       United States   91 min
# 7   United States, Ghana, Burkina Faso, United Kin...  125 min
# 9                                       United States  104 min
# 12                            Germany, Czech Republic  127 min
#
#                                            listed_in  rating  release_year  \
# 0                                      Documentaries       1          2020
# 6                           Children & Family Movies       0          2021
# 7   Dramas, Independent Movies, International Movies       2          1993
# 9                                   Comedies, Dramas       1          2021
# 12                      Dramas, International Movies       2          2021
#
#     Original  ... Males_rank_30_44  Males_rank_over_45  Females_rank_below_18  \
# 0          1  ...              7.4                 7.1                    8.0
# 6          0  ...              6.5                 5.4                    5.9
# 7          0  ...              6.7                 6.8                    0.0
# 9          0  ...              5.9                 6.2                    6.0
# 12         0  ...              5.3                 5.2                    0.0
#
#     Females_rank_18_29  Females_rank_30_44  Females_rank_over_45  \
# 0                  7.8                 7.4                   7.3
# 6                  7.2                 7.5                   7.6
# 7                  6.6                 7.9                   8.1
# 9                  6.4                 6.5                   7.2
# 12                 5.8                 6.1                   5.8
#
#     Avg_rank_males  Avg_rank_Females    Score  Score_normal
# 0              7.4               7.5  46183.4      0.788147
# 6              6.4               7.4  22590.6      0.761670
# 7              6.8               7.8   4634.0      0.741518
# 9              6.0               6.7  73161.9      0.818424
# 12             5.3               6.0   4260.6      0.741099
#
# [5 rows x 43 columns]

# %%
m = []
for x,_ in df[duration_col]["duration"].str.split(" "):
    m.append(int(x))

# %%
mins_duration["duration_int"] = m
mins_duration.head()
# Out:
#     type                       director                             title  \
# 0      0                Kirsten Johnson              Dick Johnson Is Dead
# 6      0  Robert Cullen, José Luis Ucha  My Little Pony: A New Generation
# 7      0                   Haile Gerima                           Sankofa
# 9      0                 Theodore Melfi                      The Starling
# 12     0            Christian Schwochow                      Je Suis Karl
#
#                                                  cast  \
# 0   Michael Hilow, Dick Johnson, Chad Knorr, Vasth...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country duration  \
# 0                                       United States   90 min
# 6                                       United States   91 min
# 7   United States, Ghana, Burkina Faso, United Kin...  125 min
# 9                                       United States  104 min
# 12                            Germany, Czech Republic  127 min
#
#                                            listed_in  rating  release_year  \
# 0                                      Documentaries       1          2020
# 6                           Children & Family Movies       0          2021
# 7   Dramas, Independent Movies, International Movies       2          1993
# 9                                   Comedies, Dramas       1          2021
# 12                      Dramas, International Movies       2          2021
#
#     Original  ... Males_rank_over_45  Females_rank_below_18  \
# 0          1  ...                7.1                    8.0
# 6          0  ...                5.4                    5.9
# 7          0  ...                6.8                    0.0
# 9          0  ...                6.2                    6.0
# 12         0  ...                5.2                    0.0
#
#     Females_rank_18_29  Females_rank_30_44  Females_rank_over_45  \
# 0                  7.8                 7.4                   7.3
# 6                  7.2                 7.5                   7.6
# 7                  6.6                 7.9                   8.1
# 9                  6.4                 6.5                   7.2
# 12                 5.8                 6.1                   5.8
#
#     Avg_rank_males  Avg_rank_Females    Score  Score_normal  duration_int
# 0              7.4               7.5  46183.4      0.788147            90
# 6              6.4               7.4  22590.6      0.761670            91
# 7              6.8               7.8   4634.0      0.741518           125
# 9              6.0               6.7  73161.9      0.818424           104
# 12             5.3               6.0   4260.6      0.741099           127
#
# [5 rows x 44 columns]

# %%
print("min :" , sorted(m)[0])
print("max :", sorted(m)[-1])
# Out:
# min : 3
# max : 312

# %%
bins = [0,30,50,70,90,110,130,150,320]
dic_label = {1:"0-29", 2:"30-49", 
            3:"50-69", 4:"70-89",
            5:"60-109", 6:"110-129",
            7:"130-149", 8:"150-"}

# label = [1,2,3,4,5,6,7,8]

mins_duration["duration_cate"] = pd.cut(mins_duration["duration_int"], bins = bins, labels = dic_label.values())
mins_duration["duration_cate"].value_counts()
# Out:
# 60-109     2296
# 70-89      1192
# 110-129    1073
# 130-149     445
# 50-69       417
# 150-        228
# 30-49       138
# 0-29        110
# Name: duration_cate, dtype: int64

# %%
plt.figure(figsize=(15,8))

plt.subplot(121)
sns.barplot(x = mins_duration["duration_cate"].unique(), y = mins_duration["duration_cate"].value_counts(), palette = 'RdPu' )
# plt.plot(x,y, color = "forestgreen", marker = 'o', linewidth = 2)
plt.ylabel("cnt", fontsize = 20 )
plt.xticks(fontsize = 10)
plt.title("Duration(min) Barplot", fontsize = 20, color = "white")

plt.subplot(122)
plt.boxplot(x = mins_duration["duration_cate"].value_counts())
plt.xlabel("cnt", fontsize = 20 )
plt.title("Duration(min) Boxplot", fontsize = 20, color = "white")
plt.xticks(fontsize = 10)

plt.show()

# %%
plt.figure(figsize=(15,8))
aa =df.loc[df['duration'].str.endswith('min'),'duration'] 
aa = [int(x[:-4]) for x in aa] 

plt.subplot(121)
plt.hist(aa)
plt.xticks([0,30,60,90,120,150,180,210,240,270,300,330]) 

plt.subplot(122)
plt.boxplot(aa)
plt.show()

# %%
# listed_in columns을 중복제거 후 ','로 split해서 딕셔너리에 저장
# 장르별 duration 확인
listin = df['listed_in'].dropna().unique()

listin_list = []
for x in listin:
    list_1 = x.split(',')
    for y in list_1:
        if y.strip() in listin_list:
            continue
        else:
            listin_list.append(y.strip())
listin_list
df['listed_in']  = df['listed_in'].apply(lambda x: x.split(','))

bb = {x:[] for x in listin_list}
for x in range(len(df)):
   for y in df['listed_in'][x]:
       bb[y.strip()].append(df['duration'][x])

# %%
bb
# Out:
# {'Documentaries': ['90 min',
#   '67 min',
#   '23 min',
#   '113 min',
#   '96 min',
#   '92 min',
#   '97 min',
#   '80 min',
#   '94 min',
#   '89 min',
#   '83 min',
#   '86 min',
#   '93 min',
#   '86 min',
#   '82 min',
#   '70 min',
#   '86 min',
#   '78 min',
#   '90 min',
#   '70 min',
#   '69 min',
#   '97 min',
#   '102 min',
#   '97 min',
#   '114 min',
#   '81 min',
#   '85 min',
#   '100 min',
#   '93 min',
#   '96 min',
#   '100 min',
#   '93 min',
#   '93 min',
#   '39 min',
#   '83 min',
#   '97 min',
#   '89 min',
#   '89 min',
#   '104 min',
#   '273 min',
#   '84 min',
#   '82 min',
#   '97 min',
#   '36 min',
#   '61 min',
#   '74 min',
#   '58 min',
#   '72 min',
#   '99 min',
#   '109 min',
#   '73 min',
#   '91 min',
#   '87 min',
#   '101 min',
#   '85 min',
#   '97 min',
#   '109 min',
#   '95 min',
#   '58 min',
#   '76 min',
#   '141 min',
#   '65 min',
#   '75 min',
#   '84 min',
#   '55 min',
#   '86 min',
#   '75 min',
#   '83 min',
#   '98 min',
#   '93 min',
#   '21 min',
#   '87 min',
#   '90 min',
#   '87 min',
#   '101 min',
#   '98 min',
#   '42 min',
#   '90 min',
#   '109 min',
#   '76 min',
#   '92 min',
#   '98 min',
#   '113 min',
#   '52 min',
#   '32 min',
#   '90 min',
#   '14 min',
#   '99 min',
#   '96 min',
#   '53 min',
#   '54 min',
#   '98 min',
#   '91 min',
#   '104 min',
#   '90 min',
#   '81 min',
#   '83 min',
#   '102 min',
#   '92 min',
#   '74 min',
#   '96 min',
#   '15 min',
#   '114 min',
#   '95 min',
#   '102 min',
#   '51 min',
#   '96 min',
#   '69 min',
#   '93 min',
#   '42 min',
#   '80 min',
#   '110 min',
#   '100 min',
#   '90 min',
#   '84 min',
#   '44 min',
#   '83 min',
#   '95 min',
#   '75 min',
#   '87 min',
#   '84 min',
#   '28 min',
#   '98 min',
#   '103 min',
#   '85 min',
#   '20 min',
#   '96 min',
#   '80 min',
#   '94 min',
#   '86 min',
#   '111 min',
#   '93 min',
#   '109 min',
#   '33 min',
#   '107 min',
#   '17 min',
#   '88 min',
#   '69 min',
#   '72 min',
#   '95 min',
#   '41 min',
#   '88 min',
#   '67 min',
#   '100 min',
#   '86 min',
#   '17 min',
#   '89 min',
#   '96 min',
#   '89 min',
#   '94 min',
#   '95 min',
#   '107 min',
#   '96 min',
#   '76 min',
#   '104 min',
#   '108 min',
#   '48 min',
#   '86 min',
#   '85 min',
#   '83 min',
#   '83 min',
#   '86 min',
#   '89 min',
#   '97 min',
#   '90 min',
#   '83 min',
#   '97 min',
#   '208 min',
#   '87 min',
#   '85 min',
#   '92 min',
#   '57 min',
#   '104 min',
#   '72 min',
#   '21 min',
#   '100 min',
#   '108 min',
#   '93 min',
#   '91 min',
#   '115 min',
#   '116 min',
#   '93 min',
#   '90 min',
#   '93 min',
#   '73 min',
#   '70 min',
#   '106 min',
#   '85 min',
#   '56 min',
#   '73 min',
#   '25 min',
#   '24 min',
#   '108 min',
#   '95 min',
#   '67 min',
#   '119 min',
#   '86 min',
#   '28 min',
#   '74 min',
#   '74 min',
#   '88 min',
#   '78 min',
#   '40 min',
#   '97 min',
#   '89 min',
#   '14 min',
#   '28 min',
#   '20 min',
#   '127 min',
#   '82 min',
#   '52 min',
#   '67 min',
#   '86 min',
#   '22 min',
#   '78 min',
#   '86 min',
#   '100 min',
#   '76 min',
#   '59 min',
#   '38 min',
#   '64 min',
#   '94 min',
#   '83 min',
#   '65 min',
#   '96 min',
#   '10 min',
#   '81 min',
#   '85 min',
#   '110 min',
#   '63 min',
#   '93 min',
#   '109 min',
#   '105 min',
#   '59 min',
#   '84 min',
#   '114 min',
#   '91 min',
#   '106 min',
#   '105 min',
#   '40 min',
#   '61 min',
#   '73 min',
#   '109 min',
#   '122 min',
#   '40 min',
#   '61 min',
#   '142 min',
#   '118 min',
#   '38 min',
#   '30 min',
#   '70 min',
#   '87 min',
#   '88 min',
#   '84 min',
#   '94 min',
#   '88 min',
#   '86 min',
#   '40 min',
#   '90 min',
#   '88 min',
#   '49 min',
#   '98 min',
#   '77 min',
#   '138 min',
#   '95 min',
#   '87 min',
#   '71 min',
#   '60 min',
#   '69 min',
#   '98 min',
#   '89 min',
#   '108 min',
#   '79 min',
#   '99 min',
#   '96 min',
#   '26 min',
#   '74 min',
#   '84 min',
#   '106 min',
#   '98 min',
#   '96 min',
#   '90 min',
#   '90 min',
#   '65 min',
#   '34 min',
#   '100 min',
#   '29 min',
#   '105 min',
#   '79 min',
#   '73 min',
#   '83 min',
#   '83 min',
#   '35 min',
#   '59 min',
#   '98 min',
#   '73 min',
#   '90 min',
#   '89 min',
#   '136 min',
#   '59 min',
#   '98 min',
#   '91 min',
#   '97 min',
#   '93 min',
#   '86 min',
#   '57 min',
#   '56 min',
#   '58 min',
#   '94 min',
#   '60 min',
#   '91 min',
#   '24 min',
#   '117 min',
#   '124 min',
#   '100 min',
#   '77 min',
#   '12 min',
#   '88 min',
#   '101 min',
#   '105 min',
#   '96 min',
#   '90 min',
#   '85 min',
#   '66 min',
#   '40 min',
#   '69 min',
#   '105 min',
#   '97 min',
#   '79 min',
#   '32 min',
#   '88 min',
#   '40 min',
#   '78 min',
#   '96 min',
#   '24 min',
#   '86 min',
#   '96 min',
#   '69 min',
#   '100 min',
#   '103 min',
#   '91 min',
#   '96 min',
#   '114 min',
#   '73 min',
#   '94 min',
#   '81 min',
#   '144 min',
#   '76 min',
#   '98 min',
#   '95 min',
#   '90 min',
#   '110 min',
#   '106 min',
#   '79 min',
#   '107 min',
#   '40 min',
#   '85 min',
#   '101 min',
#   '108 min',
#   '78 min',
#   '40 min',
#   '28 min',
#   '103 min',
#   '83 min',
#   '86 min',
#   '113 min',
#   '121 min',
#   '91 min',
#   '89 min',
#   '96 min',
#   '91 min',
#   '92 min',
#   '47 min',
#   '44 min',
#   '47 min',
#   '44 min',
#   '19 min',
#   '44 min',
#   '80 min',
#   '79 min',
#   '101 min',
#   '101 min',
#   '98 min',
#   '44 min',
#   '83 min',
#   '81 min',
#   '99 min',
#   '93 min',
#   '97 min',
#   '87 min',
#   '78 min',
#   '107 min',
#   '150 min',
#   '82 min',
#   '98 min',
#   '83 min',
#   '70 min',
#   '112 min',
#   '56 min',
#   '92 min',
#   '112 min',
#   '59 min',
#   '91 min',
#   '107 min',
#   '80 min',
#   '101 min',
#   '92 min',
#   '92 min',
#   '99 min',
#   '41 min',
#   '83 min',
#   '25 min',
#   '52 min',
#   '80 min',
#   '63 min',
#   '45 min',
#   '46 min',
#   '117 min',
#   '91 min',
#   '70 min',
#   '84 min',
#   '99 min',
#   '82 min',
#   '90 min',
#   '92 min',
#   '103 min',
#   '83 min',
#   '84 min',
#   '82 min',
#   '29 min',
#   '100 min',
#   '90 min',
#   '100 min',
#   '94 min',
#   '80 min',
#   '35 min',
#   '93 min',
#   '105 min',
#   '100 min',
#   '76 min',
#   '84 min',
#   '90 min',
#   '93 min',
#   '75 min',
#   '91 min',
#   '70 min',
#   '53 min',
#   '81 min',
#   '111 min',
#   '93 min',
#   '87 min',
#   '91 min',
#   '76 min',
#   '91 min',
#   '91 min',
#   '93 min',
#   '87 min',
#   '91 min',
#   '102 min',
#   '63 min',
#   '89 min',
#   '90 min',
#   '81 min',
#   '101 min',
#   '53 min',
#   '53 min',
#   '55 min',
#   '128 min',
#   '80 min',
#   '89 min',
#   '86 min',
#   '81 min',
#   '102 min',
#   '49 min',
#   '97 min',
#   '61 min',
#   '83 min',
#   '122 min',
#   '101 min',
#   '87 min',
#   '110 min',
#   '52 min',
#   '52 min',
#   '97 min',
#   '105 min',
#   '100 min',
#   '99 min',
#   '104 min',
#   '98 min',
#   '90 min',
#   '108 min',
#   '66 min',
#   '79 min',
#   '83 min',
#   '85 min',
#   '97 min',
#   '99 min',
#   '99 min',
#   '106 min',
#   '89 min',
#   '86 min',
#   '74 min',
#   '81 min',
#   '73 min',
#   '76 min',
#   '103 min',
#   '74 min',
#   '75 min',
#   '156 min',
#   '87 min',
#   '99 min',
#   '80 min',
#   '88 min',
#   '124 min',
#   '92 min',
#   '52 min',
#   '90 min',
#   '75 min',
#   '82 min',
#   '103 min',
#   '110 min',
#   '79 min',
#   '99 min',
#   '93 min',
#   '113 min',
#   '111 min',
#   '95 min',
#   '88 min',
#   '94 min',
#   '93 min',
#   '94 min',
#   '42 min',
#   '92 min',
#   '89 min',
#   '52 min',
#   '119 min',
#   '106 min',
#   '79 min',
#   '90 min',
#   '93 min',
#   '92 min',
#   '49 min',
#   '102 min',
#   '87 min',
#   '93 min',
#   '58 min',
#   '29 min',
#   '70 min',
#   '92 min',
#   '94 min',
#   '114 min',
#   '49 min',
#   '61 min',
#   '60 min',
#   '86 min',
#   '90 min',
#   '92 min',
#   '93 min',
#   '81 min',
#   '74 min',
#   '87 min',
#   '96 min',
#   '103 min',
#   '99 min',
#   '106 min',
#   '90 min',
#   '77 min',
#   '103 min',
#   '97 min',
#   '82 min',
#   '90 min',
#   '57 min',
#   '86 min',
#   '55 min',
#   '95 min',
#   '83 min',
#   '90 min',
#   '89 min',
#   '86 min',
#   '89 min',
#   '107 min',
#   '80 min',
#   '95 min',
#   '44 min',
#   '54 min',
#   '103 min',
#   '81 min',
#   '96 min',
#   '91 min',
#   '88 min',
#   '110 min',
#   '110 min',
#   '51 min',
#   '107 min',
#   '98 min',
#   '54 min',
#   '88 min',
#   '106 min',
#   '108 min',
#   '90 min',
#   '90 min',
#   '91 min',
#   '77 min',
#   '88 min',
#   '86 min',
#   '109 min',
#   '53 min',
#   '84 min',
#   '102 min',
#   '79 min',
#   '90 min',
#   '79 min',
#   '52 min',
#   '106 min',
#   '90 min',
#   '53 min',
#   '63 min',
#   '56 min',
#   '95 min',
#   '114 min',
#   '121 min',
#   '54 min',
#   '48 min',
#   '103 min',
#   '58 min',
#   '83 min',
#   '116 min',
#   '98 min',
#   '96 min',
#   '88 min',
#   '92 min',
#   '82 min',
#   '98 min',
#   '78 min',
#   '110 min',
#   '75 min',
#   '89 min',
#   '55 min',
#   '83 min',
#   '77 min',
#   '100 min',
#   '48 min',
#   '86 min',
#   '90 min',
#   '94 min',
#   '100 min',
#   '84 min',
#   '74 min',
#   '102 min',
#   '99 min',
#   '73 min',
#   '91 min',
#   '92 min',
#   '42 min',
#   '53 min',
#   '59 min',
#   '84 min',
#   '50 min',
#   '53 min',
#   '113 min',
#   '53 min',
#   '54 min',
#   '53 min',
#   '54 min',
#   '113 min',
#   '53 min',
#   '53 min',
#   '53 min',
#   '54 min',
#   '54 min',
#   '52 min',
#   '54 min',
#   '54 min',
#   '53 min',
#   '53 min',
#   '53 min',
#   '113 min',
#   '114 min',
#   '55 min',
#   '91 min',
#   '122 min',
#   '84 min',
#   '102 min',
#   '92 min',
#   '86 min',
#   '70 min',
#   '66 min',
#   '72 min',
#   '92 min',
#   '87 min',
#   '89 min',
#   '76 min',
#   '93 min',
#   '93 min',
#   '82 min',
#   '91 min',
#   '77 min',
#   '68 min',
#   '72 min',
#   '92 min',
#   '81 min',
#   '92 min',
#   '96 min',
#   '52 min',
#   '86 min',
#   '83 min',
#   '96 min',
#   '71 min',
#   '93 min',
#   '88 min',
#   '80 min',
#   '24 min',
#   '96 min',
#   '97 min',
#   '94 min',
#   '45 min',
#   '80 min',
#   '79 min',
#   '62 min',
#   '82 min',
#   '91 min',
#   '61 min',
#   '32 min',
#   '78 min',
#   '86 min',
#   '54 min',
#   '54 min',
#   '54 min',
#   '55 min',
#   '54 min',
#   '55 min',
#   '55 min',
#   '55 min',
#   '55 min',
#   '55 min',
#   '106 min',
#   '71 min',
#   '98 min',
#   '77 min',
#   '49 min',
#   '66 min',
#   '87 min',
#   '73 min',
#   '85 min',
#   '75 min',
#   '95 min',
#   '88 min',
#   '52 min',
#   '91 min',
#   '100 min',
#   '85 min',
#   '103 min',
#   '86 min',
#   '92 min',
#   '81 min',
#   '98 min',
#   '100 min',
#   '78 min',
#   '97 min',
#   '101 min',
#   '18 min',
#   '72 min',
#   '59 min',
#   '60 min',
#   '100 min',
#   '69 min',
#   '88 min',
#   '95 min',
#   '84 min',
#   '83 min',
#   '71 min',
#   '79 min',
#   '111 min',
#   '52 min',
#   '84 min',
#   '96 min',
#   '70 min',
#   '87 min',
#   '87 min',
#   '103 min',
#   '98 min',
#   '90 min',
#   '68 min',
#   '116 min',
#   '40 min',
#   '90 min',
#   '93 min',
#   '96 min',
#   '76 min',
#   '52 min',
#   '81 min',
#   '77 min',
#   '120 min',
#   '101 min',
#   '32 min',
#   '104 min',
#   '94 min',
#   '91 min',
#   '98 min',
#   '58 min',
#   '58 min',
#   '103 min',
#   '47 min',
#   '94 min',
#   '89 min',
#   '86 min',
#   '77 min',
#   '42 min',
#   '84 min',
#   '89 min',
#   '82 min',
#   '82 min',
#   '91 min',
#   '110 min',
#   '76 min',
#   '53 min',
#   '78 min',
#   '104 min',
#   '40 min',
#   '61 min',
#   '78 min',
#   '113 min',
#   '94 min',
#   '78 min',
#   '68 min',
#   '38 min',
#   '96 min',
#   '52 min',
#   '75 min',
#   '103 min',
#   '78 min',
#   '50 min',
#   '84 min',
#   '82 min',
#   '105 min',
#   '85 min',
#   '97 min',
#   '45 min'],
#  'International TV Shows': ['2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '5 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '6 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '9 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '12 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   ...],
#  'TV Dramas': ['2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '10 Seasons',
#   '4 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '7 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '17 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '6 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '13 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '5 Seasons',
#   '4 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '8 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '9 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '10 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '15 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '12 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '4 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '5 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '7 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '8 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '2 Seasons',
#   '8 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season'],
#  'TV Mysteries': ['2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '15 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '12 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '8 Seasons',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season'],
#  'Crime TV Shows': ['1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '6 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '5 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '15 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '12 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '12 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '8 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '7 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons'],
#  'TV Action & Adventure': ['1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '7 Seasons',
#   '10 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '10 Seasons',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '4 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '4 Seasons',
#   '15 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '8 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '7 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '7 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '7 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '13 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '2 Seasons',
#   '3 Seasons'],
#  'Docuseries': ['1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
# ...
#   '106 min',
#   '75 min',
#   '112 min',
#   '100 min',
#   '94 min',
#   '100 min',
#   '98 min',
#   '95 min',
#   '60 min',
#   '100 min',
#   '116 min',
#   '84 min',
#   '83 min',
#   '111 min',
#   '88 min',
#   '121 min',
#   '95 min',
#   '87 min',
#   '138 min',
#   '93 min',
#   '81 min',
#   '77 min',
#   '120 min',
#   '104 min',
#   '90 min',
#   '122 min',
#   '40 min',
#   '96 min',
#   '105 min',
#   '109 min',
#   '124 min'],
#  'Anime Series': ['1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '4 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '6 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons'],
#  'Korean TV Shows': ['2 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '6 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons'],
#  'Science & Nature TV': ['1 Season',
#   '3 Seasons',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season'],
#  'Teen TV Shows': ['1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '3 Seasons',
#   '3 Seasons',
#   '7 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '2 Seasons',
#   '3 Seasons',
#   '6 Seasons',
#   '2 Seasons',
#   '6 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '4 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season'],
#  'Cult Movies': ['117 min',
#   '104 min',
#   '94 min',
#   '101 min',
#   '106 min',
#   '95 min',
#   '103 min',
#   '98 min',
#   '91 min',
#   '126 min',
#   '118 min',
#   '88 min',
#   '94 min',
#   '103 min',
#   '94 min',
#   '134 min',
#   '160 min',
#   '110 min',
#   '110 min',
#   '94 min',
#   '102 min',
#   '95 min',
#   '47 min',
#   '88 min',
#   '143 min',
#   '90 min',
#   '137 min',
#   '82 min',
#   '102 min',
#   '81 min',
#   '99 min',
#   '98 min',
#   '113 min',
#   '87 min',
#   '172 min',
#   '95 min',
#   '118 min',
#   '98 min',
#   '101 min',
#   '88 min',
#   '122 min',
#   '105 min',
#   '86 min',
#   '114 min',
#   '99 min',
#   '101 min',
#   '118 min',
#   '93 min',
#   '84 min',
#   '79 min',
#   '90 min',
#   '77 min',
#   '154 min',
#   '114 min',
#   '153 min',
#   '112 min',
#   '94 min',
#   '106 min',
#   '113 min',
#   '96 min',
#   '102 min',
#   '66 min',
#   '85 min',
#   '97 min',
#   '161 min',
#   '85 min',
#   '83 min',
#   '108 min',
#   '94 min',
#   '96 min',
#   '158 min'],
#  'TV Shows': ['1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season'],
#  'Faith & Spirituality': ['120 min',
#   '120 min',
#   '101 min',
#   '97 min',
#   '120 min',
#   '98 min',
#   '123 min',
#   '113 min',
#   '116 min',
#   '111 min',
#   '88 min',
#   '81 min',
#   '116 min',
#   '110 min',
#   '106 min',
#   '97 min',
#   '127 min',
#   '110 min',
#   '121 min',
#   '119 min',
#   '133 min',
#   '105 min',
#   '32 min',
#   '108 min',
#   '91 min',
#   '75 min',
#   '53 min',
#   '97 min',
#   '66 min',
#   '126 min',
#   '99 min',
#   '75 min',
#   '104 min',
#   '96 min',
#   '90 min',
#   '104 min',
#   '111 min',
#   '113 min',
#   '106 min',
#   '119 min',
#   '53 min',
#   '110 min',
#   '99 min',
#   '55 min',
#   '95 min',
#   '89 min',
#   '92 min',
#   '96 min',
#   '109 min',
#   '141 min',
#   '106 min',
#   '113 min',
#   '100 min',
#   '161 min',
#   '205 min',
#   '123 min',
#   '190 min',
#   '108 min',
#   '92 min',
#   '86 min',
#   '87 min',
#   '100 min',
#   '162 min'],
#  'LGBTQ Movies': ['83 min',
#   '70 min',
#   '78 min',
#   '102 min',
#   '114 min',
#   '107 min',
#   '110 min',
#   '70 min',
#   '85 min',
#   '106 min',
#   '91 min',
#   '143 min',
#   '118 min',
#   '85 min',
#   '95 min',
#   '102 min',
#   '83 min',
#   '115 min',
#   '110 min',
#   '132 min',
#   '109 min',
#   '108 min',
#   '114 min',
#   '97 min',
#   '90 min',
#   '87 min',
#   '44 min',
#   '83 min',
#   '122 min',
#   '28 min',
#   '94 min',
#   '17 min',
#   '99 min',
#   '96 min',
#   '108 min',
#   '90 min',
#   '105 min',
#   '83 min',
#   '87 min',
#   '108 min',
#   '100 min',
#   '93 min',
#   '46 min',
#   '119 min',
#   '91 min',
#   '40 min',
#   '106 min',
#   '79 min',
#   '116 min',
#   '91 min',
#   '86 min',
#   '94 min',
#   '95 min',
#   '106 min',
#   '102 min',
#   '19 min',
#   '101 min',
#   '101 min',
#   '91 min',
#   '92 min',
#   '86 min',
#   '113 min',
#   '100 min',
#   '131 min',
#   '81 min',
#   '119 min',
#   '96 min',
#   '82 min',
#   '117 min',
#   '92 min',
#   '110 min',
#   '81 min',
#   '90 min',
#   '82 min',
#   '104 min',
#   '128 min',
#   '85 min',
#   '85 min',
#   '84 min',
#   '90 min',
#   '86 min',
#   '90 min',
#   '83 min',
#   '77 min',
#   '128 min',
#   '111 min',
#   '108 min',
#   '126 min',
#   '90 min',
#   '97 min',
#   '83 min',
#   '96 min',
#   '85 min',
#   '86 min',
#   '89 min',
#   '88 min',
#   '87 min',
#   '108 min',
#   '78 min',
#   '111 min',
#   '112 min',
#   '107 min'],
#  'Stand-Up Comedy': ['64 min',
#   '111 min',
#   '46 min',
#   '49 min',
#   '88 min',
#   '70 min',
#   '60 min',
#   '60 min',
#   '101 min',
#   '74 min',
#   '58 min',
#   '83 min',
#   '88 min',
#   '98 min',
#   '90 min',
#   '77 min',
#   '68 min',
#   '66 min',
#   '50 min',
#   '54 min',
#   '58 min',
#   '68 min',
#   '70 min',
#   '60 min',
#   '59 min',
#   '69 min',
#   '63 min',
#   '63 min',
#   '44 min',
#   '64 min',
#   '72 min',
#   '58 min',
#   '62 min',
#   '67 min',
#   '82 min',
#   '52 min',
#   '52 min',
#   '55 min',
#   '68 min',
#   '73 min',
#   '61 min',
#   '76 min',
#   '72 min',
#   '63 min',
#   '55 min',
#   '66 min',
#   '77 min',
#   '85 min',
#   '70 min',
#   '62 min',
#   '71 min',
#   '61 min',
#   '61 min',
#   '72 min',
#   '50 min',
#   '60 min',
#   '62 min',
#   '76 min',
#   '51 min',
#   '61 min',
#   '66 min',
#   '71 min',
#   '63 min',
#   '65 min',
#   '60 min',
#   '56 min',
#   '86 min',
#   '56 min',
#   '78 min',
#   '84 min',
#   '54 min',
#   '59 min',
#   '61 min',
#   '65 min',
#   '63 min',
#   '67 min',
#   '63 min',
#   '62 min',
#   '70 min',
#   '64 min',
#   '64 min',
#   '58 min',
#   '76 min',
#   '67 min',
#   '66 min',
#   '52 min',
#   '69 min',
#   '66 min',
#   '67 min',
#   '67 min',
#   '77 min',
#   '63 min',
#   '59 min',
#   '58 min',
#   '56 min',
#   '65 min',
#   '66 min',
#   '55 min',
#   '63 min',
#   '59 min',
#   '60 min',
#   '62 min',
#   '66 min',
#   '53 min',
#   '64 min',
#   '54 min',
#   '61 min',
#   '59 min',
#   '59 min',
#   '60 min',
#   '61 min',
#   '61 min',
#   '65 min',
#   '69 min',
#   '97 min',
#   '80 min',
#   '85 min',
#   '58 min',
#   '61 min',
#   '70 min',
#   '42 min',
#   '62 min',
#   '59 min',
#   '91 min',
#   '65 min',
#   '61 min',
#   '48 min',
#   '61 min',
#   '56 min',
#   '81 min',
#   '68 min',
#   '58 min',
#   '50 min',
#   '49 min',
#   '71 min',
#   '30 min',
#   '30 min',
#   '146 min',
#   '127 min',
#   '46 min',
#   '57 min',
#   '68 min',
#   '63 min',
#   '64 min',
#   '90 min',
#   '80 min',
#   '45 min',
#   '95 min',
#   '93 min',
#   '74 min',
#   '63 min',
#   '57 min',
#   '64 min',
#   '63 min',
#   '50 min',
#   '57 min',
#   '54 min',
#   '57 min',
#   '72 min',
#   '71 min',
#   '66 min',
#   '77 min',
#   '58 min',
#   '69 min',
#   '61 min',
#   '60 min',
#   '69 min',
#   '77 min',
#   '66 min',
#   '70 min',
#   '66 min',
#   '63 min',
#   '74 min',
#   '58 min',
#   '89 min',
#   '64 min',
#   '63 min',
#   '67 min',
#   '113 min',
#   '65 min',
#   '66 min',
#   '62 min',
#   '66 min',
#   '70 min',
#   '78 min',
#   '75 min',
#   '60 min',
#   '62 min',
#   '63 min',
#   '79 min',
#   '58 min',
#   '51 min',
#   '69 min',
#   '59 min',
#   '67 min',
#   '60 min',
#   '65 min',
#   '65 min',
#   '53 min',
#   '69 min',
#   '61 min',
#   '57 min',
#   '49 min',
#   '59 min',
#   '63 min',
#   '62 min',
#   '62 min',
#   '60 min',
#   '71 min',
#   '60 min',
#   '61 min',
#   '69 min',
#   '70 min',
#   '67 min',
#   '61 min',
#   '66 min',
#   '54 min',
#   '84 min',
#   '68 min',
#   '66 min',
#   '52 min',
#   '59 min',
#   '66 min',
#   '82 min',
#   '62 min',
#   '71 min',
#   '60 min',
#   '70 min',
#   '57 min',
#   '51 min',
#   '63 min',
#   '56 min',
#   '54 min',
#   '67 min',
#   '67 min',
#   '63 min',
#   '59 min',
#   '74 min',
#   '66 min',
#   '66 min',
#   '73 min',
#   '102 min',
#   '71 min',
#   '73 min',
#   '59 min',
#   '61 min',
#   '72 min',
#   '64 min',
#   '66 min',
#   '50 min',
#   '96 min',
#   '51 min',
#   '63 min',
#   '91 min',
#   '62 min',
#   '57 min',
#   '71 min',
#   '67 min',
#   '64 min',
#   '96 min',
#   '78 min',
#   '78 min',
#   '67 min',
#   '57 min',
#   '66 min',
#   '74 min',
#   '69 min',
#   '62 min',
#   '88 min',
#   '31 min',
#   '62 min',
#   '79 min',
#   '61 min',
#   '67 min',
#   '65 min',
#   '62 min',
#   '69 min',
#   '71 min',
#   '64 min',
#   '64 min',
#   '73 min',
#   '78 min',
#   '60 min',
#   '94 min',
#   '75 min',
#   '72 min',
#   '71 min',
#   '77 min',
#   '70 min',
#   '73 min',
#   '81 min',
#   '87 min',
#   '80 min',
#   '60 min',
#   '60 min',
#   '66 min',
#   '62 min',
#   '68 min',
#   '92 min',
#   '74 min',
#   '60 min',
#   '62 min',
#   '59 min',
#   '64 min',
#   '62 min',
#   '92 min',
#   '92 min',
#   '69 min',
#   '78 min',
#   '84 min',
#   '58 min',
#   '83 min',
#   '72 min',
#   '81 min',
#   '75 min',
#   '68 min',
#   '71 min',
#   '80 min',
#   '44 min',
#   '65 min',
#   '63 min',
#   '62 min',
#   '69 min',
#   '75 min',
#   '85 min',
#   '89 min',
#   '75 min',
#   '67 min',
#   '104 min',
#   '76 min',
#   '72 min'],
#  'Movies': ['115 min',
#   '39 min',
#   '36 min',
#   '34 min',
#   '36 min',
#   '72 min',
#   '92 min',
#   '59 min',
#   '44 min',
#   '22 min',
#   '22 min',
#   '23 min',
#   '51 min',
#   '50 min',
#   '23 min',
#   '82 min',
#   '25 min',
#   '89 min',
#   '81 min',
#   '46 min',
#   '69 min',
#   '51 min',
#   '44 min',
#   '29 min',
#   '26 min',
#   '47 min',
#   '52 min',
#   '22 min',
#   '33 min',
#   '35 min',
#   '29 min',
#   '53 min',
#   '48 min',
#   '55 min',
#   '45 min',
#   '75 min',
#   '71 min',
#   '49 min'],
#  'Stand-Up Comedy & Talk Shows': ['1 Season',
#   '2 Seasons',
#   '1 Season',
#   '6 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '6 Seasons',
#   '1 Season',
#   '1 Season',
#   '13 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '3 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '2 Seasons',
#   '5 Seasons',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season',
#   '1 Season'],
#  'Classic & Cult TV': ['10 Seasons',
#   '1 Season',
#   '1 Season',
#   '9 Seasons',
#   '10 Seasons',
#   '2 Seasons',
#   '2 Seasons',
#   '15 Seasons',
#   '3 Seasons',
#   '4 Seasons',
#   '12 Seasons',
#   '5 Seasons',
#   '4 Seasons',
#   '5 Seasons',
#   '3 Seasons',
#   '11 Seasons',
#   '10 Seasons',
#   '1 Season',
#   '11 Seasons',
#   '10 Seasons',
#   '5 Seasons',
#   '2 Seasons',
#   '1 Season',
#   '5 Seasons',
#   '8 Seasons',
#   '3 Seasons',
#   '2 Seasons']}

# %%
# season, min 혼용된 listed_in 확인 
for i in bb:
    if all([x.endswith('min') for x in bb[i]]) != any([x.endswith('min') for x in bb[i]]):
        print(i)

# %%
count=0
min_gen=[]
for i in bb:
    if all([x.endswith('min') for x in bb[i]]) == True:
        count+=1
        min_gen.append(i)


fig,ax = plt.subplots(3,3,figsize =(20,50))
plt.subplots_adjust(wspace = 0.3 , hspace = 0.3)

len(bb)
j=0
for i in bb:
    if j==9:break
    hist_data = [int(x.split(' ')[0]) for x in bb[i]]
    ax[j//3,j%3].hist(hist_data)
    ax[j//3,j%3].set_title(i)

    j+=1
